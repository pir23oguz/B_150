# %% [markdown]
# # Overfiting-Underfiting

# %% [raw]
# Polinom Regresyon , bağımsız değişkenler ile bağımlı değişkenler arasındaki ilişkinin n'inci derece polinomda modellendiği bir regresyon analizi şeklidir.
# Types of polinomials
# 1st degree ---> linear    b1x + b0
# 2nd degree ---> Quadratic b2x**2 + b1x + b0 2.derece
# 3rd degree ---> Cubic     b3x**3 + b2x**2 + b1x + b0 3.derece

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams["figure.figsize"] = (10,6)

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
data = np.array([[2, 3, 4]])
data
# Out:
# array([[2, 3, 4]])

# %%
trans = PolynomialFeatures(degree = 2, include_bias = False)

# %%
trans.fit(data)
# Out:
# PolynomialFeatures(include_bias=False)

# %%
trans.transform(data)
# Out:
# array([[ 2.,  3.,  4.,  4.,  6.,  8.,  9., 12., 16.]])

# %%
trans.fit_transform(data)
# Out:
# array([[ 2.,  3.,  4.,  4.,  6.,  8.,  9., 12., 16.]])

# %%
# degree 3 yapınca hem feature sayısı artıyor hemde işlemin yorumlanması zorlaşıyor işler karmaşıklaşıyor
# 2, 3, 4, 2x3, 2x4, 3x4, 2**2, 3**2, 4**2, 2x3x4, 3x2**2, 4x2**2, 2x3**2, 4x3**2, 2x4**2, 3x4**2, 2**3, 3**3, 4**3

# %% [markdown]
# # Read Dataset

# %%
df = pd.read_csv("Advertising.csv")
df
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %% [markdown]
# # Polynomial Converter

# %%
X = df.drop("sales", axis = 1)
y = df.sales

# %%
poly_conv = PolynomialFeatures(degree=2, include_bias=False)

# %%
poly_conv.fit(X)
# Out:
# PolynomialFeatures(include_bias=False)

# %%
poly_features = poly_conv.transform(X) ## Polynomial features e çevirdik

# %%
poly_features
# Out:
# array([[ 230.1 ,   37.8 ,   69.2 , ..., 1428.84, 2615.76, 4788.64],
#        [  44.5 ,   39.3 ,   45.1 , ..., 1544.49, 1772.43, 2034.01],
#        [  17.2 ,   45.9 ,   69.3 , ..., 2106.81, 3180.87, 4802.49],
#        ...,
#        [ 177.  ,    9.3 ,    6.4 , ...,   86.49,   59.52,   40.96],
#        [ 283.6 ,   42.  ,   66.2 , ..., 1764.  , 2780.4 , 4382.44],
#        [ 232.1 ,    8.6 ,    8.7 , ...,   73.96,   74.82,   75.69]])

# %%
poly_features.shape
# Out:
# (200, 9)

# %%
pd.DataFrame(poly_features, columns = ["TV", "radio", "newspaper", "TV^2", "TV&Radio", \
                                      "TV&newspaper", "Radio^2", "Radio&newspaper", "Newspaper^2"]).head()
# Out:
#       TV  radio  newspaper      TV^2  TV&Radio  TV&newspaper  Radio^2  \
# 0  230.1   37.8       69.2  52946.01   8697.78      15922.92  1428.84
# 1   44.5   39.3       45.1   1980.25   1748.85       2006.95  1544.49
# 2   17.2   45.9       69.3    295.84    789.48       1191.96  2106.81
# 3  151.5   41.3       58.5  22952.25   6256.95       8862.75  1705.69
# 4  180.8   10.8       58.4  32688.64   1952.64      10558.72   116.64
#
#    Radio&newspaper  Newspaper^2
# 0          2615.76      4788.64
# 1          1772.43      2034.01
# 2          3180.87      4802.49
# 3          2416.05      3422.25
# 4           630.72      3410.56

# %% [markdown]
# # Train | Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(poly_features, y, test_size= 0.3, random_state= 101)
# X olarak yeni oluşturduğum poly_features datasını veriyoruz.

# %%
model_poly = LinearRegression()

# %%
model_poly.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model_poly.predict(X_test)

# %%
# bagimsiz degisken 1 br arttiginda tagette meydana getireegi degisim

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Evalution on the ...

# %% [raw]
# * Simple Linear Regression:
#     * MAE      : 1.213
#     * RMSE     : 1.516
#     * r2_score : 0.8609
#
# * Polynomial 2-degree:
#     * MAE      : 0.48
#     * RMSE     : 0.66
#     * r2_score : 0.9868

# %% [markdown]
# # Let's find optimal degree of poly

# %%
def poly(d):
    train_rmse_errors = []
    test_rmse_errors = []
    number_of_features = []
    for i in range(1, d):
        polynomial_converter = PolynomialFeatures(degree = i, include_bias =False)
        poly_features = polynomial_converter.fit_transform(X)
        X_train, X_test, y_train, y_test = train_test_split(poly_features, y, test_size=0.3, random_state=101)
        model = LinearRegression(fit_intercept=True)
        model.fit(X_train, y_train)
        train_pred = model.predict(X_train)
        test_pred = model.predict(X_test)
        train_RMSE = np.sqrt(mean_squared_error(y_train,train_pred))
        test_RMSE = np.sqrt(mean_squared_error(y_test,test_pred))
        train_rmse_errors.append(train_RMSE)
        test_rmse_errors.append(test_RMSE)
        number_of_features.append(poly_features.shape[1])
    return pd.DataFrame({"train_rmse_errors": train_rmse_errors, "test_rmse_errors":test_rmse_errors, "number of features":number_of_features},
                        index=range(1,d))

# %%
poly(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15020\2368952381.py in <module>
# ----> 1 poly(10)
#
# ~\AppData\Local\Temp\ipykernel_15020\828499086.py in poly(d)
#       7         poly_features = polynomial_converter.fit_transform(X)
#       8         X_train, X_test, y_train, y_test = train_test_split(poly_features, y, test_size=0.3, random_state=101)
# ----> 9         model = LinearRegression(fit_intercept=True)
#      10         model.fit(X_train, y_train)
#      11         train_pred = model.predict(X_train)
#
# NameError: name 'LinearRegression' is not defined

# %%
plt.plot(range(1,10), poly(10)["train_rmse_errors"], label = "TRAIN")
plt.plot(range(1,10), poly(10)["test_rmse_errors"], label = "TEST")
plt.xlabel("Polynamial Complex")
plt.ylabel("RMSE")
plt.legend();
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15020\3455508295.py in <module>
# ----> 1 plt.plot(range(1,10), poly(10)["train_rmse_errors"], label = "TRAIN")
#       2 plt.plot(range(1,10), poly(10)["test_rmse_errors"], label = "TEST")
#       3 plt.xlabel("Polynamial Complex")
#       4 plt.ylabel("RMSE")
#       5 plt.legend();
#
# ~\AppData\Local\Temp\ipykernel_15020\828499086.py in poly(d)
#       7         poly_features = polynomial_converter.fit_transform(X)
#       8         X_train, X_test, y_train, y_test = train_test_split(poly_features, y, test_size=0.3, random_state=101)
# ----> 9         model = LinearRegression(fit_intercept=True)
#      10         model.fit(X_train, y_train)
#      11         train_pred = model.predict(X_train)
#
# NameError: name 'LinearRegression' is not defined

# %%
plt.plot(range(1,6), poly(6)["train_rmse_errors"], label = "TRAIN")
plt.plot(range(1,6), poly(6)["test_rmse_errors"], label = "TEST")
plt.xlabel("Polynamial Complex")
plt.ylabel("RMSE")
plt.legend();
plt.show()
# poly(6) vererek grafiği daha net görebiliyoruz.
# en iyi dere 2 veya 3 olur, tırmanış derecesine yakın dereceleri tercih etmeyiz
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15020\1888211737.py in <module>
# ----> 1 plt.plot(range(1,6), poly(6)["train_rmse_errors"], label = "TRAIN")
#       2 plt.plot(range(1,6), poly(6)["test_rmse_errors"], label = "TEST")
#       3 plt.xlabel("Polynamial Complex")
#       4 plt.ylabel("RMSE")
#       5 plt.legend();
#
# ~\AppData\Local\Temp\ipykernel_15020\828499086.py in poly(d)
#       7         poly_features = polynomial_converter.fit_transform(X)
#       8         X_train, X_test, y_train, y_test = train_test_split(poly_features, y, test_size=0.3, random_state=101)
# ----> 9         model = LinearRegression(fit_intercept=True)
#      10         model.fit(X_train, y_train)
#      11         train_pred = model.predict(X_train)
#
# NameError: name 'LinearRegression' is not defined

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# low bias high varyans = owerfitting
#
# Hiht bias low varyans = underfiting
#
# ideal olan nedir low bias low varyans

# %% [markdown]
# # Finalizing Model Choice

# %%
final_poly_conv = PolynomialFeatures(degree = 3, include_bias=False )
# 3. derece modelimizi alp eğiteceğiz

# %%
final_model = LinearRegression()

# %%
from sklearn.linear_model import LinearRegression  # onemli ibu import

# %% [markdown]
# # Prediction

# %%
new_record = [[150, 20, 15]]

# %%
new_record_poly = final_poly_conv.fit_transform(new_record)

# %%
new_record_poly
# Out:
# array([[1.500e+02, 2.000e+01, 1.500e+01, 2.250e+04, 3.000e+03, 2.250e+03,
#         4.000e+02, 3.000e+02, 2.250e+02, 3.375e+06, 4.500e+05, 3.375e+05,
#         6.000e+04, 4.500e+04, 3.375e+04, 8.000e+03, 6.000e+03, 4.500e+03,
#         3.375e+03]])

# %%
final_model.predict(new_record_poly)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15020\1212225887.py in <module>
# ----> 1 final_model.predict(new_record_poly)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     360             Returns predicted values.
#     361         """
# --> 362         return self._decision_function(X)
#     363
#     364     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in _decision_function(self, X)
#     341
#     342     def _decision_function(self, X):
# --> 343         check_is_fitted(self)
#     344
#     345         X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1220
#    1221     if not fitted:
# -> 1222         raise NotFittedError(msg % {"name": type(estimator).__name__})
#    1223
#    1224
#
# NotFittedError: This LinearRegression instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %% [markdown]
# # Overfitting

# %%
over_poly_converter = PolynomialFeatures(degree =5, include_bias =False)

over_model = LinearRegression() #modelimi over model değişkenine atadım

# %%
over_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred_over = over_model.predict(X_test)

# %%
eval_metric()b

# %% [raw]
# Testing data performance:
# --------------------------
# R2_score 	: 0.8609466508230367
# MAE 		: 1.5116692224549084
# MSE 		: 3.796797236715222
# RMSE 		: 1.9485372043446392
#
# Training data performance:
# --------------------------
# R2_score 	: 0.9055159502227753
# MAE 		: 1.1581502948072524
# MSE 		: 2.4793551789057866
# RMSE 		: 1.574596830590544

# %% [markdown]
# ![image.png](attachment:image.png)
