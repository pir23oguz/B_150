# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
plt.rcParams["figure.figsize"] = (10, 6)

import warnings
warnings.filterwarnings("ignore")

# %%
y = b0 + b1 * x1  -Simple Linear regression 

# b0; intercept (sabit) , b1 ise slope, x1'in bir birimlik değişiminin bağımlı değişkeni ne kadar değiştireceğini belirtir

X1 = TV

X2 = Radio

X3 = NewsPaper

y = b0 + b1 * x1 + b2 * x2 + b3 * x3

# %%
df = pd.read_csv("Advertising.csv")
df
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
# !pip install missingno
# Out:
# Requirement already satisfied: missingno in c:\users\pir23oguz\appdata\local\programs\python\python310\lib\site-packages (0.5.2)
# [notice] A new release of pip available: 22.2.2 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: seaborn in c:\users\pir23oguz\appdata\local\programs\python\python310\lib\site-packages (from missingno) (0.12.2)
# Requirement already satisfied: matplotlib in c:\users\pir23oguz\appdata\local\programs\python\python310\lib\site-packages (from missingno) (3.7.2)
# Requirement already satisfied: numpy in c:\users\pir23oguz\appdata\local\programs\python\python310\lib\site-packages (from missingno) (1.25.0)
# Requirement already satisfied: scipy in c:\users\pir23oguz\appdata\local\programs\python\python310\lib\site-packages (from missingno) (1.11.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\pir23oguz\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->missingno) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pir23oguz\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->missingno) (4.40.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\pir23oguz\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\pir23oguz\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->missingno) (1.1.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\pir23oguz\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->missingno) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\pir23oguz\appdata\roaming\python\python310\site-packages (from matplotlib->missingno) (23.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\pir23oguz\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\pir23oguz\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->missingno) (10.0.0)
# Requirement already satisfied: pandas>=0.25 in c:\users\pir23oguz\appdata\local\programs\python\python310\lib\site-packages (from seaborn->missingno) (2.0.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pir23oguz\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.25->seaborn->missingno) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\pir23oguz\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.25->seaborn->missingno) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\pir23oguz\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\pir23oguz\appdata\local\programs\python\python310\lib\site-packages (1.3.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\pir23oguz\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.3.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\pir23oguz\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.25.0)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\pir23oguz\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.11.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\pir23oguz\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (3.1.0)
# [notice] A new release of pip available: 22.2.2 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install sklearn
# Out:
# Requirement already satisfied: sklearn in c:\users\pir23oguz\appdata\local\programs\python\python310\lib\site-packages (0.0.post5)
# [notice] A new release of pip available: 22.2.2 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df.asape()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12704\1159767862.py in <module>
# ----> 1 df.asape()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'asape'

# %%
df.isnull().sum()
# Out:
# TV           0
# radio        0
# newspaper    0
# sales        0
# dtype: int64

# %%
import missingno as msno
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12704\1468494597.py in <module>
# ----> 1 import missingno as msno
#
# ModuleNotFoundError: No module named 'missingno'

# %%
msno.matrix

# %%
df.sort_values(by = "sales", asce)

# %%
df.describe().T
# Out:
#            count      mean        std  min     25%     50%      75%    max
# TV         200.0  147.0425  85.854236  0.7  74.375  149.75  218.825  296.4
# radio      200.0   23.2640  14.846809  0.0   9.975   22.90   36.525   49.6
# newspaper  200.0   30.5540  21.778621  0.3  12.750   25.75   45.100  114.0
# sales      200.0   14.0225   5.217457  1.6  10.375   12.90   17.400   27.0

# %%
## QutleR ICIN ORNEK

# %%
print(np.mean([100, 110, 120, 115]))
print(np.std([100, 110, 120, 115]))
# Out:
# 111.25
# 7.39509972887452

# %%
print(np.mean([100, 110, 120, 700]))
print(np.std([100, 110, 120, 700]))
# Out:
# 257.5
# 255.57533136044253

# %%
print(np.mean([100, 110, 120, 900]))
print(np.std([100, 110, 120, 900]))
# Out:
# 307.5
# 342.153109002388

# %%
sns.pairplot(df);

# %%
sns.heatmap(df.corr(), annot = True);

# %%
from scipy.stats import skew

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
for i in df.drop(columns = "sales").columns:
    print(i, skew(df[i]))
# Out:
# TV -0.06932836662244649
# radio 0.0934668451108453
# newspaper 0.8879959753085498

# %%
# Bağımsız değişkenler (features) üzerinden bağımlı değişkeni (target) tahmin etmek istiyoruz.
# Bu yüzden tüm işimiz bağımsız değişkenler ile.

# %%
for j in df.drop(columns = "sales").columns:
    g = sns.distplot(df[j], color= "b", label= "Skewness : %.2f"%(df[j].skew()))
    g = g.legend(loc= "best")
    plt.show()
