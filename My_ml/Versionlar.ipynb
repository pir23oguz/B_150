# %% [raw]
# pandas==1.4.3
# numpy==1.23.1
# seaborn==0.11.2
# matplotlib==3.5.2
# python 3.10.8

# %% [raw]
# import platform
# import matplotlib
# import seaborn as sns
# import pandas as pd
# import numpy as np
# print('Python version:', platform.python_version())
# print('Seaborn version:', sns.__version__)
# print('Matplotlib version:', matplotlib.__version__)
# print('Pandas version:', pd.__version__)
# print('Numpy version:', np.__version__)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Belirli kütüphane versiyonlarını yükleyin
pip install pandas==1.4.3 numpy==1.23.1 seaborn==0.11.2 matplotlib==3.5.2

# %% [markdown]
# pip install seaborn==0.11.2

# %% [raw]
# notebook’u istedigimiz klasorden acabilmek icin;
# 1) Python.org 3.10.8 I indir. (Kurulum yaparken ilk tik kaldirilacak, alttaki secilecek)
# 2) command prompt acilacak à “pip install notebook” yaz, enter
# 3) Kurulum bittikten sonra; acmak istedigimiz klasorun terminalinde (klasorun adres cubuguna CMD yazilarak terminal acilir) à  “jupyter notebook” yaz OK.

# %% [raw]
# Terminalden
# pip install notebook
# python --version

# %%
print(sns.__version__)

# %%
Terminalden
pip install scikit-learn==1.1.2 ile
Conda dan
conda install scikit-learn=1.1.2
yapabilirsiniz.

# %%
pip install scikit-learn==1.1.2

# %%
pip show scikit-learn
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Name: scikit-learn
# Version: 1.1.2
# Summary: A set of python modules for machine learning and data mining
# Home-page: http://scikit-learn.org
# Author:
# Author-email:
# License: new BSD
# Location: c:\users\pir23oguz\appdata\local\programs\python\python310\lib\site-packages
# Requires: joblib, numpy, scipy, threadpoolctl
# Required-by: yellowbrick
# WARNING: Ignoring invalid distribution -otebook (c:\users\pir23oguz\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -lotly (c:\users\pir23oguz\appdata\local\programs\python\python310\lib\site-packages)

# %%
# pip show scikit-learn     bununla da versionin detaylarini gorebilirsiniz

# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.5.2

# %%
pip install matplotlib==3.5.2

# %%
pip install plotly

# %%
import plotly
print(plotly.__version__)

# %%
pip install plotly==5.10

# %%
import plotly
print(plotly.__version__)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import sklearn
print(sklearn.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import sklearn
#       2 print(sklearn.__version__)
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
pip install ==1.1.2

# %%
import platform
import matplotlib
import seaborn as sns
import pandas as pd
import numpy as np
import sklearn
import yellowbrick.version
import plotly.version

print('Python version:', platform.python_version())
print('Seaborn version:', sns.__version__)
print('Matplotlib version:', matplotlib.__version__)
print('Pandas version:', pd.__version__)
print('Numpy version:', np.__version__)
print('Sklearn version:', sklearn.__version__)
print('Yellowbrick version:', yellowbrick.__version__)
print('Plotly version:', plotly.__version__)
# Out:
# Python version: 3.11.3
# Seaborn version: 0.12.2
# Matplotlib version: 3.7.1
# Pandas version: 1.5.3
# Numpy version: 1.24.3
# Sklearn version: 1.2.2
# Yellowbrick version: 1.5
# Plotly version: 5.9.0

# %%
import jupyter_core
jupyter_core.version_info["jupyter_core"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 import jupyter_core
# ----> 2 jupyter_core.version_info["jupyter_core"]
#
# TypeError: tuple indices must be integers or slices, not str

# %%
import jupyter_core
import notebook

print("Jupyter Notebook Version:", notebook.__version__)
# Out:
# Jupyter Notebook Version: 6.4.12

# %%
pip install notebook==6.4.12
# Out:
# ...
#      ---------------------------------------- 9.9/9.9 MB 3.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: notebook
#     Found existing installation: notebook 6.5.4
#     Uninstalling notebook-6.5.4:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -lotly (c:\users\pir23oguz\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -lotly (c:\users\pir23oguz\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -lotly (c:\users\pir23oguz\appdata\local\programs\python\python310\lib\site-packages)
#     WARNING: Ignoring invalid distribution -lotly (c:\users\pir23oguz\appdata\local\programs\python\python310\lib\site-packages)
# ...

# %%
pip install scikit-learn==1.1.2
# Out:
# ...
#                                               0.0/7.0 MB ? eta -:--:--
#                                               0.0/7.0 MB 1.4 MB/s eta 0:00:06
#                                               0.1/7.0 MB 1.1 MB/s eta 0:00:07
#                                               0.2/7.0 MB 1.3 MB/s eta 0:00:06
#      -                                        0.3/7.0 MB 1.6 MB/s eta 0:00:05
#      --                                       0.5/7.0 MB 2.1 MB/s eta 0:00:04
#      ---                                      0.6/7.0 MB 2.1 MB/s eta 0:00:04
#      ----                                     0.7/7.0 MB 2.3 MB/s eta 0:00:03
#      -----                                    0.9/7.0 MB 2.5 MB/s eta 0:00:03
#      ------                                   1.1/7.0 MB 2.6 MB/s eta 0:00:03
#      ------                                   1.2/7.0 MB 2.6 MB/s eta 0:00:03
#      -------                                  1.4/7.0 MB 2.7 MB/s eta 0:00:03
# ...

# %%
conda --version
# Out:
# conda 23.5.2
# Note: you may need to restart the kernel to use updated packages.
