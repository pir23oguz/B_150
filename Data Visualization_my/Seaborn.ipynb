# %% [markdown]
# # Seaborn
# https://seaborn.pydata.org/

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Seaborn icindeki data setleri

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset("tips")

# %%
tips.tail
# Out:
# <bound method NDFrame.tail of      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]>

# %%
tips.sample(5)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 208       24.27  2.03    Male    Yes   Sat  Dinner     2
# 39        31.27  5.00    Male     No   Sat  Dinner     3
# 73        25.28  5.00  Female    Yes   Sat  Dinner     2
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 123       15.95  2.00    Male     No  Thur   Lunch     2

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %% [markdown]
# ![image.png](attachment:a69f012e-33ca-4ab1-95b8-cd9cfb75c640.png)

# %% [markdown]
# ## Scatter Plot

# %%
sns.scatterplot(data = tips, x = "total_bill", y = "tip") 

plt.show()

# %%
sns.scatterplot(x = "total_bill", y = "tip", data = tips) 

plt.show()

# %%
sns.regplot(x = "total_bill", y = "tip", data = tips);

# %% [markdown]
# ## Figsize

# %%
plt.figure(figsize = (10, 5))
sns.scatterplot(x = tips["total_bill"], y = tips["tip"])
plt.show()

# %% [markdown]
# ## Hue

# %%
plt.figure(figsize = (10, 5))
sns.scatterplot(x = "total_bill", y = "tip", data = tips, hue = "smoker")
plt.show()

# %%
plt.figure(figsize = (10, 5))
sns.scatterplot(x = "total_bill", y = "tip", data = tips, hue = "sex")
plt.show()

# %%
plt.figure(figsize = (10, 5))

sns.scatterplot(x = "total_bill", y = "tip", data = tips, hue = "day" )

plt.show()

# %% [markdown]
# # Style

# %%
plt.figure(figsize = (10, 5))

sns.scatterplot(data = tips, x = "total_bill", y = "tip", style = "sex", hue = "day");

# %%
plt.figure(figsize = (10, 5))

sns.scatterplot(data = tips, x = "total_bill", y = "tip", style = "day", hue = "sex");

# %%
plt.figure(figsize = (10, 5))
sns.scatterplot(data = tips, x = "total_bill", y = "tip", style = "sex");
plt.figure(figsize = (10, 5))
sns.scatterplot(data = tips, x = "total_bill", y = "tip", style = "sex", hue = "day");
plt.figure(figsize = (10, 5))
sns.scatterplot(data = tips, x = "total_bill", y = "tip", style = "day");
plt.figure(figsize = (10, 5))
sns.scatterplot(data = tips, x = "total_bill", y = "tip", style = "day", hue = "sex");

# %%
# %matplotlib notebook
plt.figure(figsize = (8, 4))
sns.scatterplot(data = tips, x = "total_bill", y = "tip", style = "day", hue = "sex");
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# %matplotlib inline

# %%
fig, ax = plt.subplots(1, 2, figsize = (10 ,5))

sns.scatterplot(x = "total_bill", y = "tip", data = tips, style = "sex", ax = ax[0])
sns.scatterplot(x = "total_bill", y = "tip", data = tips, hue = "smoker", ax = ax[1]);

# %% [markdown]
# ## Renk

# %%
plt.figure(figsize = (10,5))
sns.scatterplot(data = tips, x = "total_bill", y = "tip", hue = "sex", palette ="plasma");

# %%
plt.figure(figsize = (10,5))
sns.scatterplot(data = tips, x = "total_bill", y = "tip", hue = "day", palette ="plasma");

# %%
plt.figure(figsize = (10,5))
sns.scatterplot(data = tips, x = "total_bill", y = "tip", hue = "day", palette ="viridis");

# %% [markdown]
# ## Yogunluk

# %%
plt.figure(figsize = (10, 5))
sns.scatterplot(data = tips, x = "total_bill", y = "tip", hue = "day", alpha = 0.5);

# %%
plt.figure(figsize = (10,5))
sns.scatterplot(data = tips, x = "total_bill", y = "tip", hue ="sex", alpha = 0.3);

# %% [markdown]
# ## little little into the middle

# %%
plt.figure(figsize = (10, 5))
sns.scatterplot(data = tips, x = "total_bill", y = "tip", hue = "day", alpha = 0.7, palette = "plasma");

# %%
plt.figure(figsize = (10, 5))
sns.scatterplot(data = tips, x = "total_bill", y = "tip", hue = "day", style = "sex", alpha = 0.7, palette = "plasma");

# %% [markdown]
# # S

# %%
plt.figure(figsize = (10, 5))
sns.scatterplot(data = tips, x = "total_bill", y = "tip", hue = "day", style = "sex", alpha = 0.7, s = 300);

# %%
plt.figure(figsize = (10, 5))
sns.scatterplot(data = tips, x = "total_bill", y = "tip", hue = "day", style = "sex", alpha = 0.5, s = 400);

# %%
plt.figure(figsize = (10, 5))
sns.scatterplot(data = tips, x = "total_bill", y = "tip", hue = "day", style = "sex", alpha = 0.7, s = 400, palette = "cubehelix");

# %% [markdown]
# # Size

# %%
plt.figure(figsize = (10, 5))
sns.scatterplot(data = tips, x = "total_bill", y = "tip", hue = "smoker", style = "day", alpha = 0.5, size = "sex");

# %%
plt.figure(figsize = (10, 5))
sns.scatterplot(data = tips, x = "total_bill", y = "tip", hue = "smoker", style = "day", size = "sex");

# %%
the relationship between ``x`` and ``y`` can be shown for different subsets
of the data using the ``hue``, ``size``, and ``style`` parameters.
# Out:
#   File "C:\Users\pir23oguz\AppData\Local\Temp\ipykernel_10428\3764659944.py", line 1
#     the relationship between ``x`` and ``y`` can be shown for different subsets
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Distribution Plot

# %%
sns.displot(x = "total_bill", data = tips);

# %%
sns.displot(x = "total_bill", data = tips, kind='hist');

# %%
sns.displot(x = "total_bill", data = tips, kind = "kde");

# %%
sns.displot(x = "total_bill", data = tips, kde = True);

# %%
sns.displot(x = "total_bill", data = tips, bins = 100);

# %%
sns.displot(x = "total_bill", data = tips, bins = 1000, kde = True);

# %%
sns.displot(x = "total_bill", data = tips, bins = 10000, kde = True);

# %%
sns.displot(x = "total_bill", data = tips, bins = 100, kde = True);

# %%
sns.displot(x = "total_bill", data = tips, kind='kde');
sns.displot(x = "total_bill", data = tips, kde=True);
sns.displot(x = "total_bill", data = tips, bins = 100);
sns.displot(x = "total_bill", data = tips, bins = 100, kde = True);

# %%
sns.displot(x = "total_bill", data = tips, bins = 1, kde = True);

# %%
sns.displot(x = "total_bill", data = tips, bins = 1,);

# %%
sns.displot(x = "total_bill", data = tips, bins = 3, kde = True);

# %%
sns.displot(x = "total_bill", data = tips, bins = 244, kde = True);

# %%
sns.displot(x = "tip", data = tips, bins = 100, kde = True);

# %%
# bins degeri arttikca sutun genisligi azalacak ve araliga az hesap adeti dusecek count sayisi azalacak,
# bins degeri azaldikca sutun genisligi artacak ve araliga daha cok hesap adeti(gozlem) dusecek count sayisi artacak

# %%
fig, ax = plt.subplots(1, 2, figsize = (10, 5))

sns.scatterplot(data = tips, x = "total_bill", y = "tip", s = 300, hue = "sex", ax = ax[0])

sns.histplot(data = tips, x = "total_bill", ax = ax[1], kde = True)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
g = sns.FacetGrid(data = tips, col = "sex", hue = "smoker")
g.map(sns.scatterplot, "total_bill", "tip", alpha = .5)  # .5 = 0.5 ayni
g.add_legend();

# %%
g = sns.FacetGrid(data = tips, col = "sex", hue = "smoker")
g.map(sns.kdeplot, "total_bill", "tip", alpha = .5, shade = True) 
g.add_legend();

# %%
sns.displot(data = tips, x = "total_bill", kind = "hist")
sns.displot(data = tips, x = "total_bill", kind = "kde");

# %%
sns.displot(data = tips, x = "total_bill", kind = "hist", kde = True, aspect = 1)

# %%
sns.displot(data = tips, x = "total_bill", kind = "hist", kde = True, aspect = 5);

# %% [markdown]
# ## Hist Plot

# %%
plt.figure(figsize = (10, 4))

sns.histplot(data = tips, x = "total_bill", bins = 50, kde = True);

# %% [markdown]
# # Doppler effect

# %%
fig, ax = plt.subplots(1, 2, figsize = (10, 5))

sns.rugplot(data = tips, x = "total_bill",height = 0.5, ax = ax[0])
sns.kdeplot(data = tips, x = "total_bill", ax = ax[1]);

# %%
fig, ax = plt.subplots(1, 2, figsize = (10, 5))

sns.rugplot(data = tips, x = "total_bill", height = 0.1, ax = ax[0])
sns.histplot(data = tips, x = "total_bill", bins = 50, kde = True, ax = ax[1]);

# %%
fig, ax = plt.subplots(1, 2, figsize = (10, 5))
sns.rugplot(data = tips, x = "total_bill", height = 0.5, ax = ax[0])
sns.kdeplot(data = tips, x = "total_bill", ax = ax[1]);

# %%
fig, ax = plt.subplots(1, 2, figsize = (10, 5))
sns.rugplot(data = tips, x = "total_bill", height = 0.1, ax = ax[0])
sns.histplot(data = tips, x = "total_bill", bins = 50, kde = True, ax = ax[1]);

# %%
sns.set(style = "dark")
sns.histplot(data = tips, x = "tip", kde = True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10428\3265152672.py in <module>
#       1 sns.set(style = "dark")
# ----> 2 sns.histplot(data = tips, x = "tip", kde = True)
#       3 plt.show()
#
# NameError: name 'tips' is not defined

# %% [markdown]
# # KDE Plot (Kernel Density Estimation)

# %%
penguins = sns.load_dataset("penguins")

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
penguins.species.unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
penguins.sex.unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
penguisns.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10428\2407856818.py in <module>
# ----> 1 penguisns.info()
#
# NameError: name 'penguisns' is not defined

# %%
sns.kdeplot(data = penguins, x = "body_mass_g");

# %%
sns.kdeplot(data = penguins, x = "body_mass_g", hue = "sex");

# %% [markdown]
# # 2D KDE graph (Izohips benzeri)

# %%
sns.kdeplot(data = tips, x = "total_bill", y = "tip");

# %%
sns.kdeplot(data = tips, x = "total_bill", y = "tip", color = "red", shade = True);

# %%
fig, ax = plt.subplots(1, 2, figsize = (10, 5))

sns.kdeplot(data = tips, x = "total_bill", y = "tip", color = "red", shade = True, ax = ax[0])
sns.kdeplot(data = tips, x = "total_bill", y = "tip", color = "red", ax = ax[1]);

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
sns.kdeplot(data=tips, x="total_bill", y="tip", color="red", shade=True, ax=ax[0])
sns.scatterplot(data=tips, x="total_bill", y="tip", color="red", ax=ax[1])
plt.show()

# %%
sns.displot(data = penguins,
           x = "body_mass_g",
           bins = 20,
           rug = True,
           kde = True);

# %%
fig, ax = plt.subplots(2, 2, figsize=(10, 5))
sns.kdeplot(data=tips, x="total_bill", y="tip", color="purple", shade=True, ax=ax[0, 0])
sns.scatterplot(data=tips, x="total_bill", y="tip", color="red", ax=ax[0, 1])
sns.histplot(data=tips, x="total_bill", y="tip", color="orange", ax=ax[1, 0])
sns.rugplot(data=tips, x="total_bill", height=0.5, ax=ax[1, 1])
plt.show()

# %%
fig, ax = plt.subplots(2, 2, figsize=(10, 5))
sns.kdeplot(data=tips, x="total_bill", y="tip", color="purple", shade=True, ax=ax[0, 0])
sns.scatterplot(data=tips, x="total_bill", y="tip", color="red", ax=ax[0, 1])
sns.histplot(data=tips, x="total_bill", y="tip", color="orange", ax=ax[1, 0])
sns.rugplot(data=tips, x="total_bill", height=0.5, ax=ax[1, 1])
plt.show()

# %%
cars = sns.load_dataset("mpg")
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
cars["cylinders"].unique()
# Out:
# array([8, 4, 6, 3, 5], dtype=int64)

# %%
sns.displot(data = cars, x = "weight", hue = "origin");

# %%
sns.displot(data = cars[cars.cylinders.isin([4, 6, 8])], x = "weight",
           col = "origin",
           row = "cylinders",
           hue = "cylinders");
